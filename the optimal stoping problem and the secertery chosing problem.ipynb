# %%
import numpy as np

# %% [markdown]
# the optimal stoping problem and the secertery chosing problem form the book Algorithms to Live By: The Computer Science of Human Decisions chapter 1

# %%
import random
import numpy as np

a = np.zeros([100,100])
for i in range(100):
  for j in range(100):
    a[i,j]= random.random()# the phenomenon takes a score form 0 to 1 


c = []

b = np.zeros([100,100])
for i in range(100):  # try to stop at 1 then 2 then 3 
  for j in range(1,100):
   b[i,j] = np.max(a[i,:j]) # the best yet
  c.append(sum(b[:99,i]))
